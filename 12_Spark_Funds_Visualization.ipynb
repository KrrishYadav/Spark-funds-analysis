# %%
import pandas as pd

companies = pd.read_csv('C:/Users/krrish/Documents/python asses/Spark_Companies.txt', sep='\t')

companies.head()
# Out:
#                              permalink                    name  \
# 0                  /Organization/-Fame                   #fame
# 1               /Organization/-Qounter                :Qounter
# 2  /Organization/-The-One-Of-Them-Inc-  (THE) ONE of THEM,Inc.
# 3                /Organization/0-6-Com                 0-6.com
# 4       /Organization/004-Technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# ...

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   permalink      66368 non-null  object
#  1   name           66367 non-null  object
#  2   homepage_url   61310 non-null  object
#  3   category_list  63220 non-null  object
#  4   status         66368 non-null  object
#  5   country_code   59410 non-null  object
#  6   state_code     57821 non-null  object
#  7   region         58338 non-null  object
#  8   city           58340 non-null  object
#  9   founded_at     51147 non-null  object
# dtypes: object(10)
# memory usage: 5.1+ MB

# %%
companies.describe()
# Out:
#                   permalink   name                homepage_url category_list  \
# count                 66368  66367                       61310         63220
# unique                66368  66102                       61191         27296
# top     /Organization/Ezway  Roost  http://www.askforoffer.com      Software
# freq                      1      4                           5          3995
#
#            status country_code state_code       region           city  \
# count       66368        59410      57821        58338          58340
# unique          4          137        311         1092           5111
# top     operating          USA         CA  SF Bay Area  San Francisco
# freq        53034        37601      12900         8804           3526
#
#         founded_at
# count        51147
# unique        3978
# top     01-01-2012
# freq          2730

# %%
rounds = pd.read_csv('C:/Users/krrish/Documents/python asses/Spark_rounds.csv')

rounds.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /ORGANIZATION/-QOUNTER
# 2               /organization/-qounter
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# ...

# %%
rounds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114949 entries, 0 to 114948
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   company_permalink        114949 non-null  object
#  1   funding_round_permalink  114949 non-null  object
#  2   funding_round_type       114949 non-null  object
#  3   funding_round_code       31140 non-null   object
#  4   funded_at                114949 non-null  object
#  5   raised_amount_usd        94959 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 5.3+ MB

# %%
rounds.describe()
# Out:
#        raised_amount_usd
# count       9.495900e+04
# mean        1.042687e+07
# std         1.148212e+08
# min         0.000000e+00
# 25%         3.225000e+05
# 50%         1.680511e+06
# 75%         7.000000e+06
# max         2.127194e+10

# %%
companies['permalink'] = companies['permalink'].str.lower()

companies.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# ...

# %%
rounds['company_permalink'] = rounds['company_permalink'].str.lower()

rounds.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /organization/-qounter
# 2               /organization/-qounter
# 3  /organization/-the-one-of-them-inc-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# ...

# %%
print(rounds.shape)

print(companies.shape)
# Out:
# (114949, 6)
# (66368, 10)

# %%
uniq_coms = companies['permalink'].unique()

len(uniq_coms)
# Out:
# 66368

# %%
uniq_rnds = rounds['company_permalink'].unique()

len(uniq_rnds)
# Out:
# 66373

# %% [markdown]
# d = []
#
# for i in uniq_rnds:
#     d.append(i not in uniq_coms)
#
# sum(d)

# %%
len(rounds['company_permalink'][~rounds['company_permalink'].isin(companies['permalink'])].unique())
# Out:
# 39

# %%
master = pd.merge(rounds, companies, left_on='company_permalink', right_on='permalink')

master.shape
# Out:
# (114909, 16)

# %%
master.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /organization/-qounter
# 2               /organization/-qounter
# 3  /organization/-the-one-of-them-inc-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd  \
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# ...

# %%
master.isna().sum()
# Out:
# company_permalink              0
# funding_round_permalink        0
# funding_round_type             0
# funding_round_code         83774
# funded_at                      0
# raised_amount_usd          19973
# permalink                      0
# name                           1
# homepage_url                6130
# category_list               3397
# status                         0
# country_code                8654
# state_code                 10920
# region                     10143
# city                       10140
# founded_at                 20502
# dtype: int64

# %%
master.shape[0]
# Out:
# 114909

# %%
round(master.isna().sum() / master.shape[0]  * 100, 2)
# Out:
# company_permalink           0.00
# funding_round_permalink     0.00
# funding_round_type          0.00
# funding_round_code         72.90
# funded_at                   0.00
# raised_amount_usd          17.38
# permalink                   0.00
# name                        0.00
# homepage_url                5.33
# category_list               2.96
# status                      0.00
# country_code                7.53
# state_code                  9.50
# region                      8.83
# city                        8.82
# founded_at                 17.84
# dtype: float64

# %% [markdown]
# master['raised_amount_usd'].fillna(master['raised_amount_usd'].mean(), inplace=True)

# %%
type_df = master.groupby('funding_round_type').mean('raised_amount_usd')

type_df
# Out:
#                        raised_amount_usd
# funding_round_type
# angel                       9.588918e+05
# convertible_note            1.455420e+06
# debt_financing              1.704353e+07
# equity_crowdfunding         5.388989e+05
# grant                       4.308623e+06
# non_equity_assistance       4.112031e+05
# post_ipo_debt               1.687046e+08
# post_ipo_equity             8.218249e+07
# private_equity              7.330859e+07
# product_crowdfunding        1.363131e+06
# secondary_market            7.964963e+07
# seed                        7.198037e+05
# undisclosed                 1.925276e+07
# venture                     1.174870e+07

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
type_df = master.groupby('funding_round_type').mean('raised_amount_usd')

type_df.reset_index(level=0, inplace=True)

type_df
# Out:
#        funding_round_type  raised_amount_usd
# 0                   angel          958891.77
# 1        convertible_note         1455420.36
# 2          debt_financing        17043526.02
# 3     equity_crowdfunding          538898.86
# 4                   grant         4308622.75
# 5   non_equity_assistance          411203.05
# 6           post_ipo_debt       168704571.82
# 7         post_ipo_equity        82182493.87
# 8          private_equity        73308593.03
# 9    product_crowdfunding         1363131.07
# 10       secondary_market        79649630.10
# 11                   seed          719803.75
# 12            undisclosed        19252764.34
# 13                venture        11748701.57

# %%
type_df[(type_df['raised_amount_usd'] > 5000000) & (type_df['raised_amount_usd'] < 15000000)]
# Out:
#    funding_round_type  raised_amount_usd
# 13            venture        11748701.57

# %%
venture_df = master[master['funding_round_type'] == 'venture']

venture_df.shape
# Out:
# (55487, 16)

# %%
cntry_df_1 = pd.DataFrame(venture_df.groupby('country_code').size().reset_index(name='no_of_rounds'))

cntry_df_1 = cntry_df_1.sort_values('no_of_rounds', ascending=False).head(n=10)

cntry_df_1
# Out:
#     country_code  no_of_rounds
# 100          USA         38372
# 31           GBR          2303
# 16           CHN          2087
# 13           CAN          1346
# 41           IND           992
# 30           FRA           985
# 44           ISR           910
# 23           DEU           786
# 27           ESP           343
# 47           JPN           318

# %% [markdown]
# # 1. US
# ## 2. UK
# ### 3. Canada

# %%
cntry_df_2 = venture_df.groupby('country_code').sum('raised_amount_usd')

cntry_df_2 = cntry_df_2.sort_values('raised_amount_usd', ascending=False).head(n=10)

cntry_df_2.reset_index(level=0, inplace=True)

cntry_df_2
# Out:
#   country_code  raised_amount_usd
# 0          USA    422510842796.00
# 1          CHN     39835418773.00
# 2          GBR     20245627416.00
# 3          IND     14391858718.00
# 4          CAN      9583332317.00
# 5          FRA      7259536732.00
# 6          ISR      6907514579.00
# 7          DEU      6346959822.00
# 8          JPN      3363676611.00
# 9          SWE      3254952563.00

# %% [markdown]
# # 1. US
# ## 2. UK
# ### 3. India

# %%
from matplotlib import pyplot as plt

# %%
plt.bar(data=type_df, x='funding_round_type', height='raised_amount_usd')
# Out:
# <BarContainer object of 14 artists>

# %%
#Setting the size of the plot
plt.figure(figsize = [14,6])

#Plotting the bar graph
plt.bar(data=type_df, x='funding_round_type', height='raised_amount_usd')

#Rotating bar ticks
plt.xticks(rotation=90)

#Display the plot
plt.show()

# %%
import seaborn as sns

plt.figure(figsize = [14,6])

fig = sns.barplot(data = type_df, x = 'funding_round_type', y = 'raised_amount_usd')

plt.xticks(rotation=90)

plt.show()

# %%
#Setting the size of the plot
plt.figure(figsize = [14,6])

#Setting the background theme
sns.set_theme()

#Plotting the bar graph
fig = sns.barplot(data = type_df, x = 'funding_round_type', y = 'raised_amount_usd')

plt.xticks(rotation=90)

#Adding label to the Y-axis
plt.ylabel("raised_amount_usd")

#Adding a title to the plot
plt.title("Average Amount per Round") 

#Display the plot
plt.show()

# %%
cntry_df_1
# Out:
#     country_code  no_of_rounds
# 100          USA         38372
# 31           GBR          2303
# 16           CHN          2087
# 13           CAN          1346
# 41           IND           992
# 30           FRA           985
# 44           ISR           910
# 23           DEU           786
# 27           ESP           343
# 47           JPN           318

# %%
cntry_df_1['English_Speaking'] = ['Yes','Yes','Yes','No','Yes','No','No','No','No','Yes']

cntry_df_1
# Out:
#     country_code  no_of_rounds English_Speaking
# 100          USA         38372              Yes
# 31           GBR          2303              Yes
# 16           CHN          2087              Yes
# 13           CAN          1346               No
# 41           IND           992              Yes
# 30           FRA           985               No
# 44           ISR           910               No
# 23           DEU           786               No
# 27           ESP           343               No
# 47           JPN           318              Yes

# %%
cntry_df_2
# Out:
#   country_code  raised_amount_usd
# 0          USA    422510842796.00
# 1          CHN     39835418773.00
# 2          GBR     20245627416.00
# 3          IND     14391858718.00
# 4          CAN      9583332317.00
# 5          FRA      7259536732.00
# 6          ISR      6907514579.00
# 7          DEU      6346959822.00
# 8          JPN      3363676611.00
# 9          SWE      3254952563.00

# %%
cntry_df_2['English_Speaking'] = ['Yes','No','Yes','Yes','Yes','No','No','No','No','No']

cntry_df_2
# Out:
#   country_code  raised_amount_usd English_Speaking
# 0          USA    422510842796.00              Yes
# 1          CHN     39835418773.00               No
# 2          GBR     20245627416.00              Yes
# 3          IND     14391858718.00              Yes
# 4          CAN      9583332317.00              Yes
# 5          FRA      7259536732.00               No
# 6          ISR      6907514579.00               No
# 7          DEU      6346959822.00               No
# 8          JPN      3363676611.00               No
# 9          SWE      3254952563.00               No

# %%
plt.figure(figsize = [14,6])

sns.set_theme()

fig = sns.barplot(data = cntry_df_2, x = 'country_code', y = 'raised_amount_usd', hue='English_Speaking')

plt.xticks(rotation=90)

plt.title("Total Amount of Investment in Top 10 Countries") 

plt.show()

# %%
#Setting the size of the plot
plt.figure(figsize = [14,6])

#Setting the background theme
sns.set_theme()

#Plotting the bar graph
fig = sns.barplot(data = cntry_df_2, x = 'English_Speaking', y = 'raised_amount_usd', hue='country_code')


#Adding label to the Y-axis
plt.ylabel("raised_amount_usd")

plt.xticks(rotation=90)

#Adding a title to the plot
plt.title("Total Amount of Investment in Top 10 Countries") 

#Display the plot
plt.show()

# %%
cntry_df = pd.merge(cntry_df_1, cntry_df_2, on='country_code')

cntry_df
# Out:
#   country_code  no_of_rounds English_Speaking_x  raised_amount_usd  \
# 0          USA         38372                Yes    422510842796.00
# 1          GBR          2303                Yes     20245627416.00
# 2          CHN          2087                Yes     39835418773.00
# 3          CAN          1346                 No      9583332317.00
# 4          IND           992                Yes     14391858718.00
# 5          FRA           985                 No      7259536732.00
# 6          ISR           910                 No      6907514579.00
# 7          DEU           786                 No      6346959822.00
# 8          JPN           318                Yes      3363676611.00
#
#   English_Speaking_y
# 0                Yes
# 1                Yes
# 2                 No
# 3                Yes
# 4                Yes
# 5                 No
# 6                 No
# 7                 No
# 8                 No

# %%
plt.figure(figsize = [14,6])

plt.scatter(data = cntry_df, x='raised_amount_usd', y='no_of_rounds')

plt.show()

# %%
master['funded_at'] = pd.to_datetime(master['funded_at'])

# %%
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114909 entries, 0 to 114908
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   company_permalink        114909 non-null  object
#  1   funding_round_permalink  114909 non-null  object
#  2   funding_round_type       114909 non-null  object
#  3   funding_round_code       31135 non-null   object
#  4   funded_at                114909 non-null  datetime64[ns]
#  5   raised_amount_usd        94936 non-null   float64
#  6   permalink                114909 non-null  object
#  7   name                     114908 non-null  object
#  8   homepage_url             108779 non-null  object
#  9   category_list            111512 non-null  object
#  10  status                   114909 non-null  object
#  11  country_code             106255 non-null  object
#  12  state_code               103989 non-null  object
# ...

# %%
master.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /organization/-qounter
# 2               /organization/-qounter
# 3  /organization/-the-one-of-them-inc-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code  funded_at  raised_amount_usd  \
# 0                  B 2015-05-01        10000000.00
# 1                  A 2014-10-14                NaN
# 2                NaN 2014-01-03          700000.00
# 3                  B 2014-01-30         3406878.00
# ...

# %%
date_df = master.groupby('funded_at').sum('raised_amount_usd')

date_df.reset_index(level=0, inplace=True)

date_df
# Out:
#       funded_at  raised_amount_usd
# 0    1960-01-01               0.00
# 1    1971-01-01          549000.00
# 2    1973-04-15               0.00
# 3    1977-05-15          250000.00
# 4    1979-01-01         1000000.00
# ...         ...                ...
# 5028 2015-12-07         5360000.00
# 5029 2015-12-08       663060245.00
# 5030 2015-12-09        15016023.00
# 5031 2015-12-10       892244479.00
# 5032 2015-12-11       400899561.00
#
# [5033 rows x 2 columns]

# %%
plt.figure(figsize = [14,6])

sns.lineplot(data=date_df, x='funded_at', y="raised_amount_usd")
  
plt.xticks(rotation = 90)

plt.show()

# %%
pd.DatetimeIndex(date_df['funded_at']).year
# Out:
# Int64Index([1960, 1971, 1973, 1977, 1979, 1980, 1982, 1982, 1982, 1983,
#             ...
#             2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015],
#            dtype='int64', name='funded_at', length=5033)

# %%
pd.DatetimeIndex(date_df['funded_at']).month
# Out:
# Int64Index([ 1,  1,  4,  5,  1,  1,  1,  1,  3,  1,
#             ...
#             12, 12, 12, 12, 12, 12, 12, 12, 12, 12],
#            dtype='int64', name='funded_at', length=5033)

# %%
new_df = date_df[(pd.DatetimeIndex(date_df['funded_at']).year == 2015) & 
                 (pd.DatetimeIndex(date_df['funded_at']).month == 1)]

plt.figure(figsize = [14,6])

sns.lineplot(data=new_df, x='funded_at', y="raised_amount_usd")
  
plt.xticks(rotation = 90)

plt.show()

# %%
plt.figure(figsize = [8,8])

plt.pie(data = cntry_df,  x='raised_amount_usd', labels='country_code')

plt.title("Average Amount per Round") 

plt.show()
